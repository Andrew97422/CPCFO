# %%
cd ../back
# Out:
# /Users/samedi/Documents/Coding/Hakatons/CPCFO/back

# %%
# from back.recommender.encode import Encoder
import pandas as pd

# %%
df = pd.read_csv('../notebooks/cache/vacancies.csv', index_col=0)

# %%
import torch
torch.save(Encoder()(df.title + ' ' + df.description), 'recommender/cache/dbembs.pt')

# %%
import numpy as np
import pandas as pd
import torch
from sentence_transformers import util
from recommender.encode import Encoder

dbembs = torch.load('recommender/cache/dbembs.pt')

import seaborn as sns
sns.heatmap(util.cos_sim(dbembs, dbembs).cpu().numpy())
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/samedi/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/samedi/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/samedi/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/samedi/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/samedi/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/samedi/nltk_data...
# ...
